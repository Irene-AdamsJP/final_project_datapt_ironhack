# %%
import pandas as pd
import numpy as np
import datetime

# %%
data = pd.read_csv('/Users/ireneadamsjdp/Downloads/noticias-economicas-sample.csv')

# %%
data.head()
# Out:
#                                                  url  \
# 0  https://www.expansion.com/economia/2020/11/24/...
# 1  https://www.expansion.com/blogs/quemada/2020/1...
# 2  https://cincodias.elpais.com/cincodias/2020/12...
# 3  https://elpais.com/sociedad/2020-12-04/illa-es...
# 4  https://www.bolsamania.com/noticias/economia/c...
#
#                                             base_url  \
# 0  https://www.expansion.com/mercados/cronica-bol...
# 1  https://www.expansion.com/mercados/cronica-bol...
# 2          https://cincodias.elpais.com/tag/ibex_35/
# 3          https://cincodias.elpais.com/tag/ibex_35/
# 4  https://www.bolsamania.com/indice/IBEX-35/noti...
#
#                               authors  \
# 0                 Christian Marquardt
# 1                                 NaN
# 2  Ediciones Cinco Días, Getty Images
# 3   Pedro Gorospe, Javier Etxezarreta
# 4                 Web Financial Group
#
#                                                title  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   url            10000 non-null  object
#  1   base_url       10000 non-null  object
#  2   authors        8581 non-null   object
#  3   title          10000 non-null  object
#  4   summary        9956 non-null   object
#  5   text           10000 non-null  object
#  6   publish_date   7540 non-null   object
#  7   top_image_url  10000 non-null  object
#  8   keywords       10000 non-null  object
#  9   insert_date    10000 non-null  object
# dtypes: object(10)
# memory usage: 781.4+ KB

# %%
count_BBVA = data['title'].str.count("BBVA")

# %%
count_BBVA.sum()
# Out:
# 108

# %%
data[data['title'].str.contains('BBVA')]
# Out:
#                                                     url  \
# 76    https://cincodias.elpais.com/cincodias/2020/12...
# 97    https://noticiasdebolsa.es/se-rompe-la-fusion-...
# 140   https://cincodias.elpais.com/cincodias/2020/11...
# 148   https://www.expansion.com/empresas/banca/2020/...
# 156   https://www.estrategiasdeinversion.com/actuali...
# ...                                                 ...
# 9419  https://www.estrategiasdeinversion.com/analisi...
# 9567  https://noticiasdebolsa.es/bbva-vende-el-80-de...
# 9735  https://www.expansion.com/sociedad/2020/10/15/...
# 9860  https://www.bolsamania.com/noticias/empresas/b...
# 9969  https://www.bolsamania.com/noticias/mercados/c...
#
#                                                base_url  \
# 76            https://cincodias.elpais.com/tag/ibex_35/
# 97                          https://noticiasdebolsa.es/
# 140           https://cincodias.elpais.com/tag/ibex_35/
# 148   https://www.expansion.com/mercados/cronica-bol...
# ...

# %%
contains_BBVA = data[data['title'].str.contains('BBVA')]

# %%
date = pd.to_datetime(contains_BBVA['publish_date'])
count_BBVA = date.groupby(date.dt.floor('d')).size().reset_index(name='count_BBVA_per_day')
print (count_BBVA)
# Out:
#    publish_date  count_BBVA_per_day
# 0    2017-11-29                   1
# 1    2018-05-24                   1
# 2    2020-08-21                   1
# 3    2020-09-15                   1
# 4    2020-10-07                   1
# 5    2020-10-15                   1
# 6    2020-10-19                   2
# 7    2020-10-21                   2
# 8    2020-10-23                   1
# 9    2020-10-27                   1
# 10   2020-10-30                   1
# 11   2020-11-08                   1
# 12   2020-11-10                   1
# 13   2020-11-11                   1
# 14   2020-11-12                   1
# 15   2020-11-16                  11
# 16   2020-11-17                   6
# 17   2020-11-18                   5
# 18   2020-11-20                   2
# 19   2020-11-21                   2
# 20   2020-11-22                   1
# 21   2020-11-25                   1
# 22   2020-11-27                   4
# 23   2020-11-28                   2
# 24   2020-11-30                   1
# ...

# %%
count_BBVA['count_BBVA_per_day'].sum()
# Out:
# 76

# %%
contains_BBVA['publish_date'].isna().sum()
# Out:
# 32

# %%
contains_BBVA['insert_date'].isna().sum()
# Out:
# 0

# %%
data[data['title'].str.contains('Bankia')]
# Out:
#                                                     url  \
# 341   https://www.finanzas.com/empresas-ibex/pharmam...
# 818   http://economia.elpais.com/economia/2020-10-21...
# 1570  https://www.expansion.com/empresas/banca/2021/...
# 1645  https://www.estrategiasdeinversion.com/analisi...
# 1914  https://noticiasdebolsa.es/los-cortos-en-banki...
# 1943  https://elpais.com/economia/2020-10-22/bankia-...
# 1982  https://www.expansion.com/empresas/banca/2020/...
# 2047  https://www.finanzas.com/empresas-ibex/bankia-...
# 2243  https://www.expansion.com/empresas/banca/2020/...
# 2548  http://economia.elpais.com/economia/2020-10-10...
# 2814  https://cincodias.elpais.com/cincodias/2020/11...
# 2910  https://cincodias.elpais.com/cincodias/2020/10...
# 3098  https://www.estrategiasdeinversion.com/actuali...
# 3379  https://elpais.com/economia/2020-10-06/el-frob...
# 3462  http://cincodias.elpais.com/cincodias/2020/09/...
# 3654  https://elpais.com/cincodias/2020/10/23/compan...
# ...

# %%
data_cotización_BBVA = pd.read_csv('/Users/ireneadamsjdp/Downloads/Datos_históricos_BBVA.csv')

# %%
data_cotización_BBVA.head()
# Out:
#         Fecha Último Apertura Máximo Mínimo    Vol. % var.
# 0  30.04.2021  4,670    4,541  4,720  4,470       -  2,63%
# 1  29.04.2021  4,550    4,520  4,621  4,495  18,17M  1,29%
# 2  28.04.2021  4,492    4,570  4,660  4,424  32,28M  0,17%
# 3  27.04.2021  4,485    4,434  4,490  4,360  19,34M  0,15%
# 4  26.04.2021  4,478    4,364  4,482  4,320  18,71M  3,36%

# %%
count_BBVA['publish_date1'] = count_BBVA['publish_date'].dt.strftime('%d.%m.%Y')
print (count_BBVA)
# Out:
#    publish_date  count_BBVA_per_day publish_date1
# 0    2017-11-29                   1    29.11.2017
# 1    2018-05-24                   1    24.05.2018
# 2    2020-08-21                   1    21.08.2020
# 3    2020-09-15                   1    15.09.2020
# 4    2020-10-07                   1    07.10.2020
# 5    2020-10-15                   1    15.10.2020
# 6    2020-10-19                   2    19.10.2020
# 7    2020-10-21                   2    21.10.2020
# 8    2020-10-23                   1    23.10.2020
# 9    2020-10-27                   1    27.10.2020
# 10   2020-10-30                   1    30.10.2020
# 11   2020-11-08                   1    08.11.2020
# 12   2020-11-10                   1    10.11.2020
# 13   2020-11-11                   1    11.11.2020
# 14   2020-11-12                   1    12.11.2020
# 15   2020-11-16                  11    16.11.2020
# 16   2020-11-17                   6    17.11.2020
# 17   2020-11-18                   5    18.11.2020
# ...

# %%
BBVA_count_and_cotización = pd.merge(count_BBVA, data_cotización_BBVA, left_on='publish_date1', right_on='Fecha')

# %%
BBVA_count_and_cotización.head()
# Out:
#   publish_date  count_BBVA_per_day publish_date1       Fecha Último Apertura  \
# 0   2017-11-29                   1    29.11.2017  29.11.2017  7,279    7,230
# 1   2018-05-24                   1    24.05.2018  24.05.2018  6,386    6,484
# 2   2020-08-21                   1    21.08.2020  21.08.2020  2,426    2,485
# 3   2020-09-15                   1    15.09.2020  15.09.2020  2,413    2,467
# 4   2020-10-07                   1    07.10.2020  07.10.2020  2,413    2,450
#
#   Máximo Mínimo    Vol.  % var.
# 0  7,322  7,202  31,36M   1,99%
# 1  6,524  6,347  19,41M  -1,25%
# 2  2,488  2,388  24,42M  -1,54%
# 3  2,476  2,400  28,19M  -3,09%
# 4  2,461  2,404  19,12M  -2,58%

# %%
BBVA_count_and_cotización['count_BBVA_per_day'].isna().sum()
# Out:
# 0

# %%
BBVA_count_and_cotización
# Out:
#    publish_date  count_BBVA_per_day publish_date1       Fecha Último Apertura  \
# 0    2017-11-29                   1    29.11.2017  29.11.2017  7,279    7,230
# 1    2018-05-24                   1    24.05.2018  24.05.2018  6,386    6,484
# 2    2020-08-21                   1    21.08.2020  21.08.2020  2,426    2,485
# 3    2020-09-15                   1    15.09.2020  15.09.2020  2,413    2,467
# 4    2020-10-07                   1    07.10.2020  07.10.2020  2,413    2,450
# 5    2020-10-15                   1    15.10.2020  15.10.2020  2,257    2,223
# 6    2020-10-19                   2    19.10.2020  19.10.2020  2,356    2,343
# 7    2020-10-21                   2    21.10.2020  21.10.2020  2,394    2,461
# 8    2020-10-23                   1    23.10.2020  23.10.2020  2,495    2,442
# 9    2020-10-27                   1    27.10.2020  27.10.2020  2,406    2,491
# 10   2020-10-30                   1    30.10.2020  30.10.2020  2,462    2,340
# ...

# %%
BBVA_count_and_cotización['count_BBVA_per_day'].sum()
# Out:
# 68

# %%
count_BBVA.columns
# Out:
# Index(['publish_date', 'count_BBVA_per_day', 'publish_date1'], dtype='object')

# %%
count_BBVA.columns = ['publish_date', 'count_BBVA_per_day', 'Fecha']

# %%
BBVA_count_and_cotización2 = pd.merge(count_BBVA, data_cotización_BBVA, on="Fecha", how="outer")

# %%
BBVA_count_and_cotización2.head()
# Out:
#   publish_date  count_BBVA_per_day       Fecha Último Apertura Máximo Mínimo  \
# 0   2017-11-29                 1.0  29.11.2017  7,279    7,230  7,322  7,202
# 1   2018-05-24                 1.0  24.05.2018  6,386    6,484  6,524  6,347
# 2   2020-08-21                 1.0  21.08.2020  2,426    2,485  2,488  2,388
# 3   2020-09-15                 1.0  15.09.2020  2,413    2,467  2,476  2,400
# 4   2020-10-07                 1.0  07.10.2020  2,413    2,450  2,461  2,404
#
#      Vol.  % var.
# 0  31,36M   1,99%
# 1  19,41M  -1,25%
# 2  24,42M  -1,54%
# 3  28,19M  -3,09%
# 4  19,12M  -2,58%

# %%
BBVA_count_and_cotización2.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1111 entries, 0 to 1110
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   publish_date        42 non-null     datetime64[ns]
#  1   count_BBVA_per_day  42 non-null     float64
#  2   Fecha               1111 non-null   object
#  3   Último              1105 non-null   object
#  4   Apertura            1105 non-null   object
#  5   Máximo              1105 non-null   object
#  6   Mínimo              1105 non-null   object
#  7   Vol.                1105 non-null   object
#  8   % var.              1105 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(7)
# memory usage: 502.9 KB

# %%
df = df.fillna(0)

# %%
data1 = pd.read_csv('/Users/ireneadamsjdp/Downloads/dataset.csv')

# %%
data1.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97300 entries, 0 to 97299
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   url            97300 non-null  object
#  1   base_url       97300 non-null  object
#  2   authors        84175 non-null  object
#  3   title          97300 non-null  object
#  4   summary        96243 non-null  object
#  5   text           97300 non-null  object
#  6   publish_date   73084 non-null  object
#  7   top_image_url  97300 non-null  object
#  8   keywords       97297 non-null  object
#  9   insert_date    97300 non-null  object
# dtypes: object(10)
# memory usage: 757.4 MB
